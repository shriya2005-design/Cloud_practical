# %%
number = int(input("Enter number to check whether it is greater than 10: "))

if number > 10:
    print("Number is greater than 10")
else:
    print("Number is 10 or less")
# Out:
# Enter number to check whether it is greater than 10: 10
# Number is 10 or less
